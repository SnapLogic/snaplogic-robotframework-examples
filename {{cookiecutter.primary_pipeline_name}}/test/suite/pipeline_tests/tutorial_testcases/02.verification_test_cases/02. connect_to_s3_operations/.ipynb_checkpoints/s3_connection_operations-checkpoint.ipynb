# %% [markdown]
# # S3 / MinIO Operations — Interactive Notebook
#
# Companion notebook for [`s3_connection_operations.robot`](./s3_connection_operations.robot).
# Each section below mirrors one Robot test case but uses raw boto3 calls so you can
# tweak parameters interactively.
#
# ## Prerequisites
#
# - Run this notebook from `make jupyter-start` (it lives inside the tools container — has `boto3` ready).
# - MinIO must be running: `make minio-start`.
# - The bucket the cells reference will be created on the fly.
#
# ## What this notebook covers
#
# 1. Connect to S3 / MinIO
# 2. Create a bucket
# 3. Upload a local file
# 4. Check object exists
# 5. Get object metadata
# 6. List bucket contents
# 7. Download a file
# 8. Clean up

# %% [markdown]
# ## 1. Setup — create an S3 client
#
# Reads credentials from environment variables; falls back to local MinIO defaults.
# Override any of these by exporting the env var before launching the notebook, or
# by editing the cell below.

# %%
import os
import boto3

S3_ENDPOINT   = os.environ.get("S3_ENDPOINT",   "http://minio:9000")
S3_ACCESS_KEY = os.environ.get("S3_ACCESS_KEY", "minioadmin")
S3_SECRET_KEY = os.environ.get("S3_SECRET_KEY", "minioadmin")
S3_REGION     = os.environ.get("S3_REGION",     "us-east-1")

# Empty endpoint = real AWS S3. Anything else = MinIO or other S3-compatible.
s3 = boto3.client(
    "s3",
    endpoint_url=S3_ENDPOINT or None,
    aws_access_key_id=S3_ACCESS_KEY,
    aws_secret_access_key=S3_SECRET_KEY,
    region_name=S3_REGION,
)

print(f"S3 client ready — endpoint: {S3_ENDPOINT or '(AWS default)'}")

# %% [markdown]
# ## 2. Validate connection — list all buckets
#
# Equivalent to the `Validate MinIO Connection` Robot keyword. If this fails, your
# credentials or endpoint are wrong.

# %%
response = s3.list_buckets()
buckets = [b["Name"] for b in response.get("Buckets", [])]
print(f"✅ Connected. Found {len(buckets)} bucket(s):")
for name in buckets:
    print(f"  - {name}")

# %% [markdown]
# ## 3. Create a bucket (idempotent)
#
# Equivalent to the `Create Bucket` Robot keyword. Skips if the bucket already exists.

# %%
BUCKET_NAME = "notebook-tutorial-bucket"
PREFIX      = "tutorial/"

from botocore.exceptions import ClientError

try:
    s3.create_bucket(Bucket=BUCKET_NAME)
    print(f"✅ Bucket created: {BUCKET_NAME}")
except ClientError as e:
    code = e.response["Error"]["Code"]
    if code in ("BucketAlreadyOwnedByYou", "BucketAlreadyExists"):
        print(f"ℹ️  Bucket already exists: {BUCKET_NAME}")
    else:
        raise

# %% [markdown]
# ## 4. Upload a local file
#
# Equivalent to the `Upload File To MinIO` Robot keyword. Uploads `sample_files/sample.txt`
# (checked into the repo next to this notebook) to `s3://<bucket>/tutorial/sample.txt`.

# %%
LOCAL_FILE = "./sample_files/sample.txt"
OBJECT_KEY = f"{PREFIX}sample.txt"

s3.upload_file(LOCAL_FILE, BUCKET_NAME, OBJECT_KEY)
print(f"📤 Uploaded {LOCAL_FILE} → s3://{BUCKET_NAME}/{OBJECT_KEY}")

# %% [markdown]
# ## 5. Check an object exists
#
# Equivalent to the `Check Object Exists` Robot keyword. Uses `head_object` —
# fast (metadata-only, no bytes downloaded).

# %%
def object_exists(bucket: str, key: str) -> bool:
    try:
        s3.head_object(Bucket=bucket, Key=key)
        return True
    except ClientError:
        return False

print(f"{OBJECT_KEY!r:50s} exists?  {object_exists(BUCKET_NAME, OBJECT_KEY)}")
print(f"{'tutorial/missing.txt'!r:50s} exists?  {object_exists(BUCKET_NAME, 'tutorial/missing.txt')}")

# %% [markdown]
# ## 6. Get object metadata
#
# Equivalent to the `Get Object Metadata` Robot keyword. Returns size, ETag,
# content-type, last-modified, etc.

# %%
metadata = s3.head_object(Bucket=BUCKET_NAME, Key=OBJECT_KEY)

print(f"Size (bytes):  {metadata['ContentLength']}")
print(f"Content-Type:  {metadata.get('ContentType', '(unknown)')}")
print(f"ETag:          {metadata['ETag']}")
print(f"LastModified:  {metadata['LastModified']}")

# %% [markdown]
# ## 7. List objects in the bucket
#
# Equivalent to the `List Objects In Bucket` Robot keyword.
#
# Tip: use the `Prefix` parameter to filter to one folder (e.g., `tutorial/data/`).

# %%
response = s3.list_objects_v2(Bucket=BUCKET_NAME, Prefix=PREFIX)
contents = response.get("Contents", [])

print(f"📋 {len(contents)} object(s) under prefix {PREFIX!r}:")
for obj in contents:
    print(f"  - {obj['Key']:40s}  size={obj['Size']:>6}  modified={obj['LastModified']}")

# %% [markdown]
# ## 8. Upload a few more files (so the next cells are interesting)
#
# Equivalent to the `Upload Two More Files` Robot test. Loops over the
# `sample_files/` directory and uploads everything ending in `.csv` or `.json`.

# %%
from pathlib import Path

for file in Path("./sample_files").glob("*"):
    if file.suffix in (".csv", ".json"):
        key = f"{PREFIX}data/{file.name}"
        s3.upload_file(str(file), BUCKET_NAME, key)
        print(f"📤 {file.name:25s} → s3://{BUCKET_NAME}/{key}")

# %% [markdown]
# ## 9. Download a file
#
# Equivalent to the `Download Single File From MinIO` Robot keyword.
# Files land under `/tmp/notebook_downloads/` inside the container, and are
# preserved between runs.

# %%
from pathlib import Path

DOWNLOAD_DIR = Path("/tmp/notebook_downloads")
DOWNLOAD_DIR.mkdir(parents=True, exist_ok=True)

local_path = DOWNLOAD_DIR / "sample.txt"
s3.download_file(BUCKET_NAME, OBJECT_KEY, str(local_path))

print(f"📥 Downloaded → {local_path} ({local_path.stat().st_size} bytes)")
print("\nFile content:")
print(local_path.read_text())

# %% [markdown]
# ## 10. Verify object size
#
# Equivalent to the `Verify All Files Are Non Empty In Bucket` Robot keyword.

# %%
all_objects = s3.list_objects_v2(Bucket=BUCKET_NAME, Prefix=PREFIX).get("Contents", [])

for obj in all_objects:
    icon = "✅" if obj["Size"] > 0 else "❌"
    print(f"{icon} {obj['Key']:40s}  {obj['Size']:>6} bytes")

# %% [markdown]
# ## 11. Clean up — delete every object under the tutorial prefix
#
# Equivalent to the `Clean Bucket By Prefix` Robot keyword.

# %%
to_delete = s3.list_objects_v2(Bucket=BUCKET_NAME, Prefix=PREFIX).get("Contents", [])

for obj in to_delete:
    s3.delete_object(Bucket=BUCKET_NAME, Key=obj["Key"])
    print(f"🗑️  deleted {obj['Key']}")

print(f"\nDeleted {len(to_delete)} object(s).")

# %% [markdown]
# ## 12. Delete the bucket itself (optional)
#
# Equivalent to the `Delete Bucket` Robot keyword. Only succeeds if the bucket is empty —
# the cleanup cell above ensures that.

# %%
try:
    s3.delete_bucket(Bucket=BUCKET_NAME)
    print(f"✅ Bucket deleted: {BUCKET_NAME}")
except ClientError as e:
    code = e.response["Error"]["Code"]
    if code in ("NoSuchBucket", "NotFound"):
        print(f"ℹ️  Bucket already gone: {BUCKET_NAME}")
    elif code == "BucketNotEmpty":
        print(f"⚠️  Bucket not empty — re-run the cleanup cell first.")
    else:
        raise

# %% [markdown]
# ## What's next
#
# - **Tweak `BUCKET_NAME` / `PREFIX`** at the top to point at your own bucket.
# - **Point at AWS S3** by setting `S3_ENDPOINT=""` (empty) and exporting AWS keys.
# - **Read the full Robot test suite** for keyword equivalents:
#   [`s3_connection_operations.robot`](./s3_connection_operations.robot)
# - **Read the keyword library** that wraps these calls:
#   [`minio.resource`](../../../../../resources/minio/minio.resource)
